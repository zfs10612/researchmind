# %% [markdown]
# <a href="https://colab.research.google.com/github/zfs10612/researchmind/blob/main/week1/attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# Then to save a notebook to GitHub, the easiest method from Colab is:

# **File → Save a copy in GitHub** → select your `researchmind` repo → choose a folder like `week1/` → save.

# ---

# **Step 3: Structure your repo like a researcher**

# Create these folders as you go:
# ```
# researchmind/
# ├── week1/
# │   ├── attention.ipynb        ← today's task
# │   └── rag_pipeline.ipynb
# ├── week2/
# ├── week3/
# └── README.md
# ```

# ---

# **Step 4: Write a one-line README for now**

# In the README on GitHub, just put:
# ```
# # ResearchMind
# AI research engineering prep — attention, training internals, RAG, RL alignment.
